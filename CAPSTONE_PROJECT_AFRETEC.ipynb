# %% [markdown]
# IMPORTING THE DATASET

# %% [markdown]
# ML Final Project for Supervised Learning on Student Depression Dataset

# %% [markdown]
# Dataset from: https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:/Users/student/Desktop/Dataset/Student Depression Dataset.xlsx")

# %%
df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                  5
# 1           8  Female   24      Bangalore    Student                  2
# 2          26    Male   31       Srinagar    Student                  3
# 3          30  Female   28       Varanasi    Student                  3
# 4          32  Female   25         Jaipur    Student                  4
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                  5
# 27897  140686    Male   27       Ludhiana    Student                  2
# 27898  140689    Male   31      Faridabad    Student                  3
# 27899  140690  Female   18       Ludhiana    Student                  5
# 27900  140699    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                        int64
# City                                      object
# Profession                                object
# Academic Pressure                          int64
# Work Pressure                              int64
# CGPA                                     float64
# Study Satisfaction                         int64
# Job Satisfaction                           int64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                           int64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  int64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  int64
#  6   Work Pressure                          27901 non-null  int64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  int64
#  9   Job Satisfaction                       27901 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# ENCODING COLUMNS

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df=df.rename(columns={"Academic Pressure":"Acad_pressure","Work Pressure":"Work_pressure","Study Satisfaction":"Study_satisfaction","Job Satisfaction":"Job_satisfaction","Sleep Duration":"Sleep_duration","Dietary Habits":"Dietary_habits","Have you ever had suicidal thoughts ?":"Suicidal_thoughts","Work/Study Hours":"Wort_study_hours","Financial Stress":"Financial_stress","Family History of Mental Illness":"Family_history_mental_illness"})

# %%
df.head
# Out:
# <bound method NDFrame.head of            id  Gender  Age           City Profession  Acad_pressure  \
# 0           2    Male   33  Visakhapatnam    Student              5
# 1           8  Female   24      Bangalore    Student              2
# 2          26    Male   31       Srinagar    Student              3
# 3          30  Female   28       Varanasi    Student              3
# 4          32  Female   25         Jaipur    Student              4
# ...       ...     ...  ...            ...        ...            ...
# 27896  140685  Female   27          Surat    Student              5
# 27897  140686    Male   27       Ludhiana    Student              2
# 27898  140689    Male   31      Faridabad    Student              3
# 27899  140690  Female   18       Ludhiana    Student              5
# 27900  140699    Male   27          Patna    Student              4
#
#        Work_pressure  CGPA  Study_satisfaction  Job_satisfaction  \
# ...

# %%
df=df.assign(Financial_stress=df['Financial_stress'].fillna(df['Financial_stress'].median()))
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#    id  Gender  Age           City Profession  Acad_pressure  Work_pressure  \
# 0   2    Male   33  Visakhapatnam    Student              5              0
# 1   8  Female   24      Bangalore    Student              2              0
#
#    CGPA  Study_satisfaction  Job_satisfaction Sleep_duration Dietary_habits  \
# 0  8.97                   2                 0      5-6 hours        Healthy
# 1  5.90                   5                 0      5-6 hours       Moderate
#
#     Degree Suicidal_thoughts  Wort_study_hours  Financial_stress  \
# 0  B.Pharm               Yes                 3               1.0
# 1      BSc                No                 3               2.0
#
#   Family_history_mental_illness  Depression
# 0                            No           1
# 1                           Yes           0

# %%
df["Degree"]
# Out:
# 0         B.Pharm
# 1             BSc
# 2              BA
# 3             BCA
# 4          M.Tech
#            ...
# 27896    Class 12
# 27897         MSc
# 27898          MD
# 27899    Class 12
# 27900         BCA
# Name: Degree, Length: 27901, dtype: object

# %%
df['Sleep_duration'].value_counts()
# Out:
# Sleep_duration
# Less than 5 hours    8310
# 7-8 hours            7346
# 5-6 hours            6183
# More than 8 hours    6044
# Others                 18
# Name: count, dtype: int64

# %% [markdown]
# Descriptive Analysis

# %%
df["Age"].agg(["max","min","mean"])
# Out:
# max     59.0000
# min     18.0000
# mean    25.8223
# Name: Age, dtype: float64

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 1    16336
# 0    11565
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Depression', data=df)
# Out:
# <Axes: xlabel='Depression', ylabel='count'>

# %%
df['Depression'].value_counts(normalize=True)*100
# Out:
# Depression
# 1    58.549873
# 0    41.450127
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(df['Gender'].value_counts(), autopct='%1.1f%%', labels=['Female', 'Male'])
# Out:
# ([<matplotlib.patches.Wedge at 0x21c2e37c050>,
# ...
#  [Text(-0.19667542820716774, 1.0822748153493766, 'Female'),
#   Text(0.19667542820716807, -1.0822748153493766, 'Male')],
#  [Text(-0.10727750629481876, 0.5903317174632963, '55.7%'),
#   Text(0.10727750629481894, -0.5903317174632963, '44.3%')])

# %%
import seaborn as sns

# %%
sns.countplot(x="Sleep_duration", hue="Depression", data=df)
plt.title("Sleep Duration vs Depression")
plt.xlabel("Sleep Duration")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# DISTRIBUTION OF AGES

# %%
sns.histplot(df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.drop(columns=['id'], inplace=True, errors='ignore')
df
# Out:
#        Gender  Age           City Profession  Acad_pressure  Work_pressure  \
# 0        Male   33  Visakhapatnam    Student              5              0
# 1      Female   24      Bangalore    Student              2              0
# 2        Male   31       Srinagar    Student              3              0
# 3      Female   28       Varanasi    Student              3              0
# 4      Female   25         Jaipur    Student              4              0
# ...       ...  ...            ...        ...            ...            ...
# 27896  Female   27          Surat    Student              5              0
# 27897    Male   27       Ludhiana    Student              2              0
# 27898    Male   31      Faridabad    Student              3              0
# 27899  Female   18       Ludhiana    Student              5              0
# 27900    Male   27          Patna    Student              4              0
#
# ...

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['Gender',
#  'City',
#  'Profession',
#  'Sleep_duration',
#  'Dietary_habits',
#  'Degree',
#  'Suicidal_thoughts',
#  'Family_history_mental_illness']

# %%
from sklearn.preprocessing import LabelEncoder
categorical_cols = ['Gender', 'City', 'Profession', 'Degree', 'Dietary_habits', 
                    'Sleep_duration', 'Suicidal_thoughts', 
                    'Family_history_mental_illness']


le = LabelEncoder()
for col in categorical_cols:
    df[col] = df[col].astype(str).str.strip("'")  # Remove extra quotes
    df[col] = le.fit_transform(df[col])

# %%
# Check if all values are numeric
print(df.dtypes)
# Out:
# Gender                             int32
# Age                                int64
# City                               int32
# Profession                         int32
# Acad_pressure                      int64
# Work_pressure                      int64
# CGPA                             float64
# Study_satisfaction                 int64
# Job_satisfaction                   int64
# Sleep_duration                     int32
# Dietary_habits                     int32
# Degree                             int32
# Suicidal_thoughts                  int32
# Wort_study_hours                   int64
# Financial_stress                 float64
# Family_history_mental_illness      int32
# Depression                         int64
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Gradient Boosting": GradientBoostingClassifier()
}

# %% [markdown]
# ## Selecting Features & Target Variable

# %%
Predictors=df.drop("Depression",axis=1)

# %%
Predictors.head(2)
# Out:
#    Gender  Age  City  Profession  Acad_pressure  Work_pressure  CGPA  \
# 0       1   33    51          11              5              0  8.97
# 1       0   24     3          11              2              0  5.90
#
#    Study_satisfaction  Job_satisfaction  Sleep_duration  Dietary_habits  \
# 0                   2                 0               0               0
# 1                   5                 0               0               1
#
#    Degree  Suicidal_thoughts  Wort_study_hours  Financial_stress  \
# 0       3                  1                 3               1.0
# 1      10                  0                 3               2.0
#
#    Family_history_mental_illness
# 0                              0
# 1                              1

# %%
Target=df["Depression"]
Target.head(4)
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# Name: Depression, dtype: int64

# %%
Predictors.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Profession', 'Acad_pressure', 'Work_pressure',
#        'CGPA', 'Study_satisfaction', 'Job_satisfaction', 'Sleep_duration',
#        'Dietary_habits', 'Degree', 'Suicidal_thoughts', 'Wort_study_hours',
#        'Financial_stress', 'Family_history_mental_illness'],
#       dtype='object')

# %%
#### TRAIN AND TEST SPLIT
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    Predictors, Target, test_size=0.3, random_state=42
)

# %%
X_train
# Out:
#        Gender  Age  City  Profession  Acad_pressure  Work_pressure  CGPA  \
# 19571       1   21    44          11              5              0  5.58
# 12078       1   18     1          11              5              0  6.08
# 26427       1   18    11          11              4              0  7.77
# 21881       1   29    51          11              3              0  7.48
# 12049       1   33    14          11              4              0  8.52
# ...       ...  ...   ...         ...            ...            ...   ...
# 21575       0   34     2          11              2              0  7.79
# 5390        1   20    32          11              3              0  5.82
# 860         1   18    21          11              5              0  6.37
# 15795       0   18     6          11              3              0  7.21
# 23654       1   34    45          11              3              0  7.64
#
#        Study_satisfaction  Job_satisfaction  Sleep_duration  Dietary_habits  \
# ...

# %%
X_test
# Out:
#        Gender  Age  City  Profession  Acad_pressure  Work_pressure  CGPA  \
# 19981       0   29    17          11              2              0  8.53
# 16551       1   28    44          11              2              0  5.57
# 7640        1   34    49          11              3              0  5.12
# 21266       1   21    32          11              5              0  8.95
# 15759       1   25    51          11              5              0  7.87
# ...       ...  ...   ...         ...            ...            ...   ...
# 18596       0   31    21          11              5              0  5.83
# 10606       0   28    37          11              1              0  5.71
# 21263       1   21    38          11              1              0  6.03
# 8778        1   25    24          11              5              0  5.88
# 17657       0   28    17          11              5              0  9.96
#
#        Study_satisfaction  Job_satisfaction  Sleep_duration  Dietary_habits  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
logit=LogisticRegression(max_iter=1000)
logit.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_Predicton=logit.predict(X_test)
Y_Predicton
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
conf_matrx=confusion_matrix(y_test,Y_Predicton)
conf_matrx
# Out:
# array([[2786,  719],
#        [ 600, 4266]], dtype=int64)

# %%
table_conf_matrix=pd.DataFrame(conf_matrx,index=['Actual 0' ,'Actual 1'],columns=['Predicted 0','Predicted 1'])
table_conf_matrix
# Out:
#           Predicted 0  Predicted 1
# Actual 0         2786          719
# Actual 1          600         4266

# %% [markdown]
# Probability of depressed(1) or not depressed(0)

# %% [markdown]
# CONFUSION MATRIX RESULTS

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
disp=ConfusionMatrixDisplay(confusion_matrix=conf_matrx,display_labels=['0','1'])
disp.plot(cmap='Blues')
plt.title("confusion Matrix Results")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
Modal={"Logostic":LogisticRegression(max_iter=100),
       "Decision":DecisionTreeClassifier(),
       "KNN":KNeighborsClassifier(),
       "RANDOM":RandomForestClassifier(),
       "Gradient":GradientBoostingClassifier()}

# %%
for name, model in Modal.items():
    fitted_modal=model.fit(X_train, y_train)
    print("fitted_modal")
# Out:
# fitted_modal
# fitted_modal
# fitted_modal
# fitted_modal
# fitted_modal

# %%
Y_pred1=model.predict(X_test)
Y_prob1=model.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,auc,roc_curve
import pandas as pd

results = []

for name, model in Modal.items():
    # Train model
    model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_test)

    # Probabilities for ROC-AUC
    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:, 1]
        roc = roc_auc_score(y_test, y_prob)
    else:
        roc = None  

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1_score": f1_score(y_test, y_pred),
        "ROC_auc": roc
    })

# Final results table
summary_df = pd.DataFrame(results)
summary_df
# Out:
#       Model  Accuracy  Precision    Recall  F1_score   ROC_auc
# 0  Logostic  0.842432   0.855767  0.876695  0.866105  0.917023
# 1  Decision  0.754749   0.795049  0.778874  0.786878  0.750065
# 2       KNN  0.744117   0.757955  0.822441  0.788882  0.802457
# 3    RANDOM  0.833353   0.850394  0.865598  0.857929  0.911063
# 4  Gradient  0.840401   0.852718  0.876901  0.864640  0.918125

# %%
logistic_model = LogisticRegression(max_iter=1000, random_state=42)

# Train model
logistic_model.fit(X_train, y_train)

# Predictions
y_pred = logistic_model.predict(X_test)
y_prob = logistic_model.predict_proba(X_test)[:, 1]   # probabilities (IMPORTANT)

# Evaluation table
results = [{
    "Model": "Logistic Regression",
    "Accuracy": accuracy_score(y_test, y_pred),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_score": f1_score(y_test, y_pred),
    "ROC_auc": roc_auc_score(y_test, y_prob)
}]

summary_df = pd.DataFrame(results)
summary_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1_score   ROC_auc
# 0  Logistic Regression  0.842432   0.855767  0.876695  0.866105  0.917023

# %%
# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, lw=2, label=f"Logistic Regression (AUC = {roc_auc_score(y_test, y_prob):.3f})")
plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – Logistic Regression")
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_curve, auc

# 1. Initialize the models
models = {
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'KNN':KNeighborsClassifier(n_neighbors=5)
}

plt.figure(figsize=(7, 4))

# 2. Train and plot each model
for name, model in models.items():
    model.fit(X_train, y_train)
    y_probs = model.predict_proba(X_test)[:, 1]
    
    fpr, tpr, _ = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)
    
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.3f})')

# 3. Formatting the plot
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparison of ROC Curves')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %%
#Initialize and Train the Model
# Random Forest is excellent for determining feature importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = rf.feature_importances_
feature_names = Predictors.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances
}).sort_values(by='Importance', ascending=False)



# Display the sorted importance table
print(feature_importance_df)
# Out:
#                           Feature  Importance
# 12              Suicidal_thoughts    0.229737
# 4                   Acad_pressure    0.162879
# 14               Financial_stress    0.091689
# 6                            CGPA    0.085465
# 1                             Age    0.083684
# 2                            City    0.071920
# 13               Wort_study_hours    0.069726
# 11                         Degree    0.061678
# 7              Study_satisfaction    0.043371
# 10                 Dietary_habits    0.035750
# 9                  Sleep_duration    0.033231
# 0                          Gender    0.015461
# 15  Family_history_mental_illness    0.014984
# 3                      Profession    0.000359
# 8                Job_satisfaction    0.000045
# 5                   Work_pressure    0.000021

# %%
# 9. Visualize the Important Predictors
plt.figure(figsize=(3, 4))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Top Predictors of Student Depression')
plt.xlabel('Importance Score (Random Forest)')
plt.ylabel('Predictor Variable')
plt.show()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_24220\1541001455.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
